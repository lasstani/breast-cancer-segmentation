# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2
import warnings
warnings.filterwarnings('ignore')

from scipy import ndimage as ndi
from skimage.color import label2rgb
from skimage import morphology
import math

from matplotlib import pylab as pylab
from skimage import io
from skimage import color
from skimage.feature import canny
from skimage.filters import sobel

path= r'D:\tanya\Downloads\all-mias\mdb105.pgm'
im = cv2.imread(path)

imgray = cv2.cvtColor(im, cv2.COLOR_BGR2GRAY)

# %%
def viewImage(image, name_of_window):
    cv2.namedWindow(name_of_window, cv2.WINDOW_NORMAL)
    cv2.imshow(name_of_window, image)
    cv2.waitKey(0)
    cv2.destroyAllWindows()
#viewImage(img,'img')

# %%
def minMaxNormalise(img):

    norm_img = (img - img.min()) / (img.max() - img.min())

    return norm_img

# %%
norm_img = minMaxNormalise(imgray)

# %%
plt.imshow(norm_img)

# %%
def globalBinarise(img, thresh, maxval):

    binarised_img = np.zeros(img.shape)
    binarised_img[img >= thresh] = maxval

    return binarised_img

# %%
binarised_img = globalBinarise(norm_img, 0.2 ,1)

# %%
def editMask(mask, ksize=(23, 23), operation="open"):

    kernel = cv2.getStructuringElement(shape=cv2.MORPH_RECT, ksize=ksize)
    
    if operation == "open":
        edited_mask = cv2.morphologyEx(mask, cv2.MORPH_OPEN, kernel)
    elif operation == "close":
        edited_mask = cv2.morphologyEx(mask, cv2.MORPH_CLOSE, kernel)

    # Then dilate
    edited_mask = cv2.morphologyEx(edited_mask, cv2.MORPH_DILATE, kernel)

    return edited_mask

# %%
edited_mask = editMask(binarised_img, ksize=(23, 23), operation="open")

# %%
edited_mask = edited_mask.astype(np.uint8)

# %%
def sortContoursByArea(contours, reverse=True):

    # Sort contours based on contour area.
    sorted_contours = sorted(contours, key=cv2.contourArea, reverse=reverse)

    # Construct the list of corresponding bounding boxes.
    bounding_boxes = [cv2.boundingRect(c) for c in sorted_contours]

    return sorted_contours, bounding_boxes

# %%
def xLargestBlobs(mask, top_x=None, reverse=True):

    # Find all contours from binarised image.
    # Note: parts of the image that you want to get should be white.
    contours, hierarchy = cv2.findContours(
        image=mask, mode=cv2.RETR_EXTERNAL, method=cv2.CHAIN_APPROX_NONE
    )

    n_contours = len(contours)

    # Only get largest blob if there is at least 1 contour.
    if n_contours > 0:

        # Make sure that the number of contours to keep is at most equal
        # to the number of contours present in the mask.
        if n_contours < top_x or top_x == None:
            top_x = n_contours

        # Sort contours based on contour area.
        sorted_contours, bounding_boxes = sortContoursByArea(
            contours=contours, reverse=reverse
        )

        # Get the top X largest contours.
        X_largest_contours = sorted_contours[0:top_x]

        # Create black canvas to draw contours on.
        to_draw_on = np.zeros(mask.shape, dtype = 'int')

        # Draw contours in X_largest_contours.
        X_largest_blobs = cv2.drawContours(
            image=to_draw_on,  # Draw the contours on `to_draw_on`.
            contours=X_largest_contours,  # List of contours to draw.
            contourIdx=-1,  # Draw all contours in `contours`.
            color=1,  # Draw the contours in white.
            thickness=-1,  # Thickness of the contour lines.
        )

    return n_contours, X_largest_blobs

# %%
_, xlargest_mask  = xLargestBlobs(mask=edited_mask, top_x=1, reverse=True)

# %%
def applyMask(img, mask):

    masked_img = img.copy()
    masked_img[mask == 0] = 0

    return masked_img

# %%
masked_img=applyMask(img=norm_img, mask = xlargest_mask)

# %%
def checkLRFlip(mask):

    # Get number of rows and columns in the image.
    nrows, ncols = mask.shape
    x_center = ncols // 2
    y_center = nrows // 2

    # Sum down each column.
    col_sum = mask.sum(axis=0)
    # Sum across each row.
    row_sum = mask.sum(axis=1)

    left_sum = sum(col_sum[0:x_center])
    right_sum = sum(col_sum[x_center:-1])

    if left_sum < right_sum:
        LR_flip = True
    else:
        LR_flip = False

    return LR_flip


def makeLRFlip(img):

    flipped_img = np.fliplr(img)

    return flipped_img

# %%
lr_flip = checkLRFlip(mask=xlargest_mask)
if lr_flip:
    flipped_img = makeLRFlip(img=masked_img)
elif not lr_flip:
    flipped_img = masked_img

# %%
def clahe(img, clip=2.0, tile=(8, 8)):

    img = cv2.normalize(
        img,
        None,
        alpha=0,
        beta=255,
        norm_type=cv2.NORM_MINMAX,
        dtype=cv2.CV_32F,
    )
    img_uint8 = img.astype("uint8")

    clahe_create = cv2.createCLAHE(clipLimit=clip, tileGridSize=tile)
    clahe_img = clahe_create.apply(img_uint8)

    return clahe_img

# %%
clahe_img = clahe(flipped_img, clip=1.0, tile=(8, 8))
viewImage(clahe_img,"clahe_img")

# %% [markdown]
# unique, counts = np.unique(clahe_img, return_counts=True)
# dict1 = dict(zip(unique, counts))
# un = list(dict1.keys())
# vesa = list(dict1.values())

# %% [markdown]
# vesa[0] = 13000
# vesa[1] = 13000

# %% [markdown]
# import seaborn as sns
# vesa = np.array(vesa)
# import matplotlib.pyplot as plt
# fig, ax = plt.subplots(figsize=(15, 7))
# p=sns.barplot(x = un, y  = vesa)
# p.set(xlabel = 'значения яркости', ylabel = 'число пискселей')
# #plt.xticks(rotation=90)
# p.tick_params(bottom=False)
# p.set_title('Гистограмма яркостей')

# %%
clahe_img = clahe_img.astype(np.uint8)

# %%
def read_image(image):
    image = color.rgb2gray(image)
    return image

# %%
def apply_canny(image):
    canny_img = canny(image,0.5)
    return sobel(canny_img)

# %%
from skimage.transform import hough_line, hough_line_peaks

def get_hough_lines(canny_img):
    h, theta, d = hough_line(canny_img)
    lines = list()
    print('\nAll hough lines')
    for _, angle, dist in zip(*hough_line_peaks(h, theta, d)):
        print("Angle: {:.2f}, Dist: {:.2f}".format(np.degrees(angle), dist))
        x1 = 0
        y1 = (dist - x1 * np.cos(angle)) / np.sin(angle)
        x2 = canny_img.shape[1]
        y2 = (dist - x2 * np.cos(angle)) / np.sin(angle)
        lines.append({
            'dist': dist,
            'angle': np.degrees(angle),
            'point1': [x1, y1],
            'point2': [x2, y2]
        })
    print(lines)
    
    return lines

# %%
def shortlist_lines(lines):
    MIN_ANGLE = 10
    MAX_ANGLE = 50
    MIN_DIST  = 50
    MAX_DIST  = 700
    
    shortlisted_lines = [x for x in lines if 
                          (x['dist']>=MIN_DIST) &
                          (x['dist']<=MAX_DIST) &
                          (x['angle']>=MIN_ANGLE) &
                          (x['angle']<=MAX_ANGLE)
                        ]
    print('\nShorlisted lines')
    for i in shortlisted_lines:
        print("Angle: {:.2f}, Dist: {:.2f}".format(i['angle'], i['dist']))
        
    return shortlisted_lines

# %%
from skimage.draw import polygon

def remove_pectoral(shortlisted_lines):
    shortlisted_lines.sort(key = lambda x: x['dist'])
    pectoral_line = shortlisted_lines[0]
    d = pectoral_line['dist']
    theta = np.radians(pectoral_line['angle'])
    
    x_intercept = d/np.cos(theta)
    y_intercept = d/np.sin(theta)
    
    return polygon([0, 0, y_intercept], [0, x_intercept, 0], image.shape)

# %%
image = read_image(clahe_img)
canny_image = apply_canny(image)
lines = get_hough_lines(canny_image)
shortlisted_lines = shortlist_lines(lines)
    
rr, cc = remove_pectoral(shortlisted_lines)
image[rr, cc] = 0
plt.imshow(image,cmap=pylab.cm.gray)
# Out:
# All hough lines
# Angle: -0.50, Dist: 184.56
# Angle: 1.51, Dist: 326.61
# Angle: 0.50, Dist: 339.62
# Angle: 3.52, Dist: 356.62
# Angle: -1.51, Dist: 309.61
# Angle: -7.54, Dist: 226.58
# Angle: 13.58, Dist: 418.64
# Angle: -8.55, Dist: 168.56
# Angle: -13.58, Dist: 150.55
# Angle: -5.53, Dist: 240.58
# Angle: -4.53, Dist: 292.60
# Angle: -1.51, Dist: 278.60
# Angle: 0.50, Dist: 213.57
# Angle: -10.56, Dist: 200.57
# Angle: 8.55, Dist: 390.63
# Angle: 10.56, Dist: 378.63
# Angle: -15.59, Dist: 134.55
# Angle: -14.58, Dist: 107.54
# Angle: -17.60, Dist: 59.52
# Angle: -14.58, Dist: 94.53
# Angle: -19.61, Dist: 36.51
# Angle: -24.64, Dist: -10.50
# Angle: -27.65, Dist: -112.54
# Angle: -21.62, Dist: 14.51
# Angle: 17.60, Dist: 462.66
# Angle: -20.61, Dist: 435.65
# Angle: -33.69, Dist: -33.51
# Angle: -44.75, Dist: -348.62
# Angle: -28.66, Dist: -126.54
# Angle: -46.76, Dist: -375.63
# Angle: -24.64, Dist: -66.52
# Angle: -45.75, Dist: -361.62
# Angle: 90.00, Dist: 2.50
# ...

# %%
image = np.array(image, dtype = 'int')

# %%
image[image == 0] = 2

# %%
path1 = r'D:\tanya\Downloads'

# %%
import os
cv2.imwrite(os.path.join(path1 , 'waka271.jpg'), image)
# Out:
# True

# %%
class FRiS_Tax:
    def __init__(self, k=20, tol=0.001, max_iter=300):
        self.k = k
        self.tol = tol
        self.max_iter = max_iter

    def fit(self,data):

        unique, counts = np.unique(data, return_counts=True)
        dict1 = dict(zip(unique, counts))
        un = list(dict1.keys())
        vesa = list(dict1.values())
        N = 1024**2
                     
        self.stolp = {}
        
        d = []

        for i in range(len(un)):
            s=0
            for j in range(len(un)):
                s += vesa[j]*abs(un[i]-un[j]) 
            d.append(s/N)
        r = min(d) #r*
        
        r1_1 = np.zeros((len(un), len(un)), dtype = 'float')            
        F = []

        for i in range(len(un)):
            s=0
            for j in range(len(un)):
                r1_1[i][j] = abs(un[i]-un[j])
                s += (vesa[j])*(r - r1_1[i][j])/(r + r1_1[i][j]) 
            F.append(s/N)
                     
        self.stolp[0] = un[F.index(max(F))]
        
        # потом надо найти остальные столпы 
        #====================================================================================
        #ПОИСК СТОЛПОВ

        for k in range(1, self.k):        
            r11 = np.zeros((len(un), len(un)), dtype = 'float')
            F1 = []

            for i in range(len(un)):
                s=0
        
                for j in range(len(un)):
                    g = []
                    for stolp in self.stolp:
                
                        g.append(np.abs(un[j]-self.stolp[stolp]))
                    
                    r11[i][j] = min(abs(un[i]-un[j]), min(g))
            
                    s += (vesa[j])*(r - r11[i][j])/(r + r11[i][j])  # ничего не меняется если убрать -ves[i]
                F1.append(s/N)
                     
            self.stolp[k] = un[F1.index(max(F1))]
            
        for i in range(300):
            self.classifications = {}
    
            for i in range(self.k):
                self.classifications[i] = []

            for featureset in un:
                distances = [np.abs(featureset-self.stolp[stolp]) for stolp in self.stolp]
                classification = distances.index(min(distances))
                self.classifications[classification].append(featureset)
                
            prev_stolp = dict(self.stolp) 
            
            for classification in self.classifications:
                F2=[]
                for a in list(self.classifications.values())[classification]:
            
                    r1=abs(a-self.stolp[classification])
            
                    distances =  []
            
                    for stolp in self.stolp:
                        distances.append(np.abs(a-self.stolp[stolp]))
                        if (stolp == classification):
                            distances[stolp] = 1000000
           
                    r2 = min(distances)
            
                    s = (r2 - r1)/(r2 + r1)
                    F2.append(s)

                self.stolp[classification] = self.classifications[classification][F2.index(max(F2))]
            
            optimized = True

            for c in self.stolp:
                original_stolp = prev_stolp[c]
                current_stolp= self.stolp[c]
                if np.sum((current_stolp-original_stolp)/original_stolp*100.0) > self.tol:
                    #print(np.sum((current_stolp-original_stolp)/original_stolp*100.0))
                    optimized = False

            if optimized:
                break

# %%
model = FRiS_Tax()
model.fit(image)

# %%
a = np.zeros((1024,1024), dtype= 'int')
for classification in model.classifications:
    for i in range(1024):
        for j in range(1024):
            if (image[i][j] in list(model.classifications.values())[classification]):
                a[i][j] = classification

# %%
fig, axes = plt.subplots(1, 2, figsize=(15, 7))
axes[0].imshow(a)
axes[1].imshow(clahe_img, cmap=plt.cm.gray)

# %%
ff =list(model.stolp.keys())[list(model.stolp.values()).index(max(list(model.stolp.values())))]

# %%
b = np.zeros((1024,1024))

for i in range(1024):
    for j in range(1024):
        if a[i][j] == ff:
            b[i][j] = 1

# %%
fill_coins = ndi.binary_fill_holes(b)

fig, ax = plt.subplots(figsize=(7, 7))
ax.imshow(fill_coins, cmap=plt.cm.gray)

# %%
coins_cleaned = morphology.remove_small_objects(fill_coins, 1000)

fig, ax = plt.subplots(figsize=(7, 7))
ax.imshow(coins_cleaned, cmap=plt.cm.gray)

# %%
coins_cleaned = coins_cleaned.astype(np.uint8)
contours, hierarchy = cv2.findContours(coins_cleaned, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)

# %%
contoured_img = cv2.drawContours(clahe_img, contours, -1, (255, 0, 0), 2)

# %%
contoured_img = cv2.cvtColor(contoured_img, cv2.COLOR_BGR2RGB)

# %%
viewImage(contoured_img,"contoured_img")

# %%
clahe_img = clahe(flipped_img, clip=1.0, tile=(8, 8))
viewImage(clahe_img,"clahe_img")

# %%
image = read_image(clahe_img)
canny_image = apply_canny(image)
lines = get_hough_lines(canny_image)
shortlisted_lines = shortlist_lines(lines)
    
rr, cc = remove_pectoral(shortlisted_lines)
image[rr, cc] = 0

# %%
fill_coins12 = ndi.binary_fill_holes(b)

fig, ax = plt.subplots(figsize=(15, 7))
ax.imshow(fill_coins12, cmap=plt.cm.gray)

# %%
coins_cleaned12 = morphology.remove_small_objects(fill_coins12, 1000)

fig, ax = plt.subplots(figsize=(15, 7))
ax.imshow(coins_cleaned12, cmap=plt.cm.gray)

# %%
coins_cleaned12 = coins_cleaned12.astype(np.uint8)
contours12, hierarchy12 = cv2.findContours(coins_cleaned12, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)

# %%
contoured_img12 = cv2.drawContours(contoured_img, contours12, -1, (0, 255, 0), 2)

# %%
contoured_img12 = cv2.cvtColor(contoured_img12, cv2.COLOR_BGR2RGB)

# %%
viewImage(contoured_img12,"contoured_img")

# %%
fill_coins20 = ndi.binary_fill_holes(b)

fig, ax = plt.subplots(figsize=(15, 7))
ax.imshow(fill_coins20, cmap=plt.cm.gray)

# %%
coins_cleaned20 = morphology.remove_small_objects(fill_coins20, 1000)

fig, ax = plt.subplots(figsize=(15, 7))
ax.imshow(coins_cleaned20, cmap=plt.cm.gray)

# %%
coins_cleaned20 = coins_cleaned20.astype(np.uint8)
contours20, hierarchy20 = cv2.findContours(coins_cleaned20, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)

# %%
contoured_img20 = cv2.drawContours(contoured_img12, contours20, -1, (0, 0, 255), 2)

# %%
contoured_img20 = cv2.cvtColor(contoured_img20, cv2.COLOR_BGR2RGB)

# %%
viewImage(contoured_img20,"contoured_img20")

# %%
image_label_overlay = cv2.circle(contoured_img20, (1023-516, 1023-279), 98, (255, 20, 147), 3)                                                                          
fig, ax = plt.subplots(figsize=(15, 7))       
ax.imshow(image_label_overlay)

# %%
import os

path = r'D:\tanya\Downloads'
cv2.imwrite(os.path.join(path , 'fris-cluster на 105 6 12 20 без мышцы.jpg'), contoured_img20)
# Out:
# True

# %%
labeled_coins, _ = ndi.label(coins_cleaned)
image_label_overlay = label2rgb(labeled_coins, image=clahe_img, bg_label=0)

fig, ax = plt.subplots(figsize=(7, 7))
ax.imshow(image_label_overlay)

# %%
x =  493 
y =  125 
radius = 49

# %%
image_label_overlay = cv2.circle(image_label_overlay, (1023-x, 1023-y), radius, (255, 0, 0), 3)                                                                                          
fig, ax = plt.subplots(figsize=(15, 7))  
ax.imshow(image_label_overlay)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
coins_cleaned = coins_cleaned.astype('int')
square_b = cv2.countNonZero(coins_cleaned)

# %%
mask = np.zeros((1024,1024)) 
for i in range(1024):
    for j in range(1024):
        if (1023-i-y)**2 + (1023-j-x)**2 <= radius **2:
            mask[i][j] = 1

# %%
fig, ax = plt.subplots(figsize=(7, 7))
plt.imshow(mask)

# %%
square_circle = math.pi * radius ** 2
print('Площадь круга {:.2f}'.format(square_circle))
# Out:
# Площадь круга 7542.96

# %%
result = mask *  coins_cleaned
    
square_result = cv2.countNonZero(result)
kriterii = (2*square_result)/ (square_circle + square_b)

# %%
kriterii
# Out:
# 0.4391118287669979
